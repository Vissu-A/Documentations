# %% [markdown]
# The efficiency of any data structure is rated based on some basic operations like **Accessing, Searching, Inserting and Deleting**.

# %% [markdown]
# Every data structure has its own advantages, some are good at searching, some are good at both inserting and accessing and some are good at deleting.

# %% [markdown]
# Based on the operation we want to perform we will choose the data structure to use. Let say we have 2 data structures X, Y. so, X is good at inserting and Y is good at searching.

# %% [markdown]
# We have a scenario like finding the element then we should go for data structure Y. we have a scenario like data is coming continuously and we want to store it then we should go for data structure X.

# %% [markdown]
# <br>

# %% [markdown]
# ## **Array**

# %% [markdown]
# Array is most commonly and widely used data structure in computer programming.

# %% [markdown]
# Array is nothing but a collection of elements or items that are stored at contiguous memory locations.

# %% [markdown]
# Storing collection/group of similar data type elements/items as a single entity is nothing but an array.

# %% [markdown]
# **Note:** The elements in an array should be same data type.

# %% [markdown]
# Each array will have 3 properties associated.<br>
# > 1.	Name of the array
# > 2.	Type of the array
# > 3.	Size of the array<br><br>
# > **Ex:**<br>
# > Names = [‘vissu’, ‘dinesh’, ‘dileep’]  **type = String, size = 3**<br>
# > Salaries = [25000, 35000, 30000]       **type = Integer, size = 3**

# %% [markdown]
# ### Parallel arrays
# Parallel arrays are nothing but two or more arrays having same size and each element in an array relate to the element in other array at same location.<br>
# <br>If we look at above two arrays "names" and "salaries", we can say that vissu having salary of 25000. This means they both elements are related with each other.

# %% [markdown]
# **NOTE:** The size of an array is fixed upon creation of the array. This means while creating an array we need to specify the size of array. This size can’t be changed later. Size represents the total number of elements that we can store in an array.
